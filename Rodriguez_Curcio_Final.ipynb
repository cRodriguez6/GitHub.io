# %% [markdown]
# <a href="https://colab.research.google.com/github/cRodriguez6/GitHub.io/blob/main/Rodriguez_Curcio_Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# TSA Effficency Data Sets
#
# By Connor Rodriguez and Jaeden Curcio

# %% [markdown]
# Imports:

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Project Goal
